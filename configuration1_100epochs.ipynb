# %% [markdown]
# # Mini Project - Modified ResNet Architecture with CIFAR-10 images

# %% [markdown]
# **Goal:** In this mini-project we are tasked with coming up
# with a modified residual network (ResNet)
# architecture with the **highest test accuracy** on the CIFAR-10 image classification dataset, under the
# constraint that our model has **no more than 5 million parameters**.

# %% [markdown]
# ## Dataset loading and importing packages

# %% [markdown]
# We would be using **CIFAR-10 image classification dataset** which has the classes: ‘airplane’, ‘automobile’, ‘bird’, ‘cat’, ‘deer’, ‘dog’, ‘frog’, ‘horse’, ‘ship’, ‘truck’. The images in CIFAR-10 are of size 3x32x32, i.e. 3-channel color images of 32x32 pixels in size. This dataset can be loaded using the **torchvision** package.

# %%
# Importing packages
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn

import torchvision
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

import random

from torchsummary import summary
from tabulate import tabulate

from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
# Ensure that you create a folder dlf22_mini_project in your drive account
from google.colab import drive
drive.mount('/content/drive')
proj_root = '/content/drive/MyDrive/dlf22_mini_project'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ###Training, Validation and Testing Dataloaders
#
# The training and validation dataloaders are split from the train directory using random seed shuffling of indices. The training dataloader then uses train transformations and batch size 128 which the validation dataloader uses the test transformations with batch size 100. The testing dataset comes from test directory, and dataloader uses test transformations and batch size 100.

# %%
# Loading and Transforming dataset
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# Train dataset
trainset = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True, transform=transform_train)

# trainloader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=True, num_workers=2)

# Validation dataset
valid_dataset = torchvision.datasets.CIFAR10(
        root='./data', train=True,
        download=True, transform=transform_test,
    )

# Train - validation split
num_train = len(trainset)
indices = list(range(num_train))
# Size of validation dataset
valid_size = 0.1
split = int(np.floor(valid_size * num_train))
# Shuffle the dataset indices
random_seed = random.seed(30)
np.random.seed(random_seed)
np.random.shuffle(indices)
train_idx, valid_idx = indices[split:], indices[:split]
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# Dataloaders for train and validation dataset
train_iterator= torch.utils.data.DataLoader(
        trainset, batch_size=128, sampler=train_sampler,
        num_workers=2
    )
valid_iterator = torch.utils.data.DataLoader(
        valid_dataset, batch_size=100, sampler=valid_sampler,
        num_workers=2
    )

    
# Test dataset and loader
testset = torchvision.datasets.CIFAR10(
    root='./data', train=False, download=True, transform=transform_test)
test_iterator = torch.utils.data.DataLoader(
    testset, batch_size=100, shuffle=False, num_workers=2)

# Target classes
# classes = ('plane', 'car', 'bird', 'cat', 'deer',
#            'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Define our device as the first visible cuda device if we have CUDA available
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %% [markdown]
# ### Plotting some examples
#
# Now let's check some of the images data we have

# %%
def plot_images(images, labels, classes, normalize = False):

    n_images = len(images)

    rows = int(np.sqrt(n_images))
    cols = int(np.sqrt(n_images))

    fig = plt.figure(figsize = (10, 10))

    for i in range(rows*cols):

        ax = fig.add_subplot(rows, cols, i+1)
        
        image = images[i]

        if normalize:
            image_min = image.min()
            image_max = image.max()
            image.clamp_(min = image_min, max = image_max)
            image.add_(-image_min).div_(image_max - image_min + 1e-5)

        ax.imshow(image.permute(1, 2, 0).cpu().numpy())
        ax.set_title(classes[labels[i]])
        ax.axis('off')

# %%
N_IMAGES = 25

images, labels = zip(*[(image, label) for image, label in 
                           [trainset[i] for i in range(N_IMAGES)]])

classes = testset.classes

# %%
plot_images(images, labels, classes, normalize = True)

# %% [markdown]
# ## Defining the ResNet

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %% [markdown]
# Created a custom Resnet function to test all configurations

# %%
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_channels = [64, 128, 256, 512], strides = [1, 2, 2, 2], linear_in= 512, in_planes = 64, avg_pool_size = 4, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = in_planes

        self.conv1 = nn.Conv2d(3, in_planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(in_planes)
        self.layers_list = []
        for i in range(len(num_blocks)):
            # Makes layers based on the num_blocks, num_channels, strides given
            self.layers_list.append(self._make_layer(block, num_channels[i], num_blocks[i], stride=strides[i]))
        self.layer1 = nn.Sequential(*self.layers_list)
        self.linear = nn.Linear(linear_in*block.expansion, num_classes)
        self.avg_pool_size = avg_pool_size

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = F.avg_pool2d(out, self.avg_pool_size)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %% [markdown]
# ## Testing different configurations of Resnet-18

# %% [markdown]
# ### Setting up different configurations

# %% [markdown]
# Experimented with:
#
# Configuration 1 - Reducing number of blocks
#
# Configuration 2 - Reducing number of layers and blocks
#
# Configuration 3 - Reducing number of layers, blocks and increasing number of channels
#
# Configuration 4 - Reducing number of layers, blocks, increasing number of channels and modifying average pool kernel size
#
# Configuration 5 - Same configuration as configuration 3 but changing number of initial residual layer to 128 i.e., 128->128->256->512
#
# Configuration 6 - Same configuration as configuration 4 but changing number of initial residual layer to 128 i.e., 128->128->256->512

# %%
models = []

# %%
# Original Resnet-18
net = ResNet(BasicBlock, [2, 2, 2, 2], [64, 128, 256, 512], [1, 2, 2, 2])
net = net.to(device)
summary(net, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %%
# Reducing number of residual blocks
net1 = ResNet(BasicBlock, [2, 1, 1, 1], [64, 128, 256, 512], [1, 2, 2, 2])
models.append(net1)
net1 = net1.to(device)
summary(net1, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-21            [-1, 256, 8, 8]             512
#            Conv2d-22            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-23            [-1, 256, 8, 8]             512
#            Conv2d-24            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-25            [-1, 256, 8, 8]             512
#        BasicBlock-26            [-1, 256, 8, 8]               0
#            Conv2d-27            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-28            [-1, 512, 4, 4]           1,024
#            Conv2d-29            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-30            [-1, 512, 4, 4]           1,024
#            Conv2d-31            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-32            [-1, 512, 4, 4]           1,024
#        BasicBlock-33            [-1, 512, 4, 4]               0
#            Linear-34                   [-1, 10]           5,130
# ================================================================
# Total params: 4,977,226
# Trainable params: 4,977,226
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 9.06
# Params size (MB): 18.99
# Estimated Total Size (MB): 28.06
# ----------------------------------------------------------------

# %%
# residual layer reduction and residual block modification 
net2 = ResNet(BasicBlock, [4, 4, 3], [64, 128, 256], [1, 2, 2], 1024)
models.append(net2)
net2 = net2.to(device)
summary(net2, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-14           [-1, 64, 32, 32]             128
#            Conv2d-15           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-16           [-1, 64, 32, 32]             128
#        BasicBlock-17           [-1, 64, 32, 32]               0
#            Conv2d-18           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-19           [-1, 64, 32, 32]             128
#            Conv2d-20           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-21           [-1, 64, 32, 32]             128
#        BasicBlock-22           [-1, 64, 32, 32]               0
#            Conv2d-23          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-24          [-1, 128, 16, 16]             256
#            Conv2d-25          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-26          [-1, 128, 16, 16]             256
#            Conv2d-27          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-28          [-1, 128, 16, 16]             256
#        BasicBlock-29          [-1, 128, 16, 16]               0
#            Conv2d-30          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-31          [-1, 128, 16, 16]             256
#            Conv2d-32          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-33          [-1, 128, 16, 16]             256
#        BasicBlock-34          [-1, 128, 16, 16]               0
#            Conv2d-35          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-36          [-1, 128, 16, 16]             256
#            Conv2d-37          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-38          [-1, 128, 16, 16]             256
#        BasicBlock-39          [-1, 128, 16, 16]               0
#            Conv2d-40          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-41          [-1, 128, 16, 16]             256
#            Conv2d-42          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-43          [-1, 128, 16, 16]             256
#        BasicBlock-44          [-1, 128, 16, 16]               0
#            Conv2d-45            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-46            [-1, 256, 8, 8]             512
#            Conv2d-47            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-48            [-1, 256, 8, 8]             512
#            Conv2d-49            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-50            [-1, 256, 8, 8]             512
#        BasicBlock-51            [-1, 256, 8, 8]               0
#            Conv2d-52            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-53            [-1, 256, 8, 8]             512
#            Conv2d-54            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-55            [-1, 256, 8, 8]             512
#        BasicBlock-56            [-1, 256, 8, 8]               0
#            Conv2d-57            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-58            [-1, 256, 8, 8]             512
#            Conv2d-59            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-60            [-1, 256, 8, 8]             512
#        BasicBlock-61            [-1, 256, 8, 8]               0
#            Linear-62                   [-1, 10]          10,250
# ================================================================
# Total params: 4,704,842
# Trainable params: 4,704,842
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 18.63
# Params size (MB): 17.95
# Estimated Total Size (MB): 36.58
# ----------------------------------------------------------------

# %%
# reducing residual layer, reducing residual block and increasing number of chan modification
net3 = ResNet(BasicBlock, [1, 1, 1], [128, 256, 512], [1, 2, 2], 2048)
models.append(net3)
net3 = net3.to(device)
summary(net3, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3          [-1, 128, 32, 32]          73,728
#        BatchNorm2d-4          [-1, 128, 32, 32]             256
#             Conv2d-5          [-1, 128, 32, 32]         147,456
#        BatchNorm2d-6          [-1, 128, 32, 32]             256
#             Conv2d-7          [-1, 128, 32, 32]           8,192
#        BatchNorm2d-8          [-1, 128, 32, 32]             256
#         BasicBlock-9          [-1, 128, 32, 32]               0
#            Conv2d-10          [-1, 256, 16, 16]         294,912
#       BatchNorm2d-11          [-1, 256, 16, 16]             512
#            Conv2d-12          [-1, 256, 16, 16]         589,824
#       BatchNorm2d-13          [-1, 256, 16, 16]             512
#            Conv2d-14          [-1, 256, 16, 16]          32,768
#       BatchNorm2d-15          [-1, 256, 16, 16]             512
#        BasicBlock-16          [-1, 256, 16, 16]               0
#            Conv2d-17            [-1, 512, 8, 8]       1,179,648
#       BatchNorm2d-18            [-1, 512, 8, 8]           1,024
#            Conv2d-19            [-1, 512, 8, 8]       2,359,296
#       BatchNorm2d-20            [-1, 512, 8, 8]           1,024
#            Conv2d-21            [-1, 512, 8, 8]         131,072
#       BatchNorm2d-22            [-1, 512, 8, 8]           1,024
#        BasicBlock-23            [-1, 512, 8, 8]               0
#            Linear-24                   [-1, 10]          20,490
# ================================================================
# Total params: 4,844,618
# Trainable params: 4,844,618
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 13.25
# Params size (MB): 18.48
# Estimated Total Size (MB): 31.74
# ----------------------------------------------------------------

# %%
# reducing residual layer, reducing residual block, increasing number of channels, modifying average pool kernel size 
net4 = ResNet(BasicBlock, [1, 1, 1], [128, 256, 512], [1, 2, 2], 8192, avg_pool_size = 2)
models.append(net4)
net4 = net4.to(device)
summary(net4, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3          [-1, 128, 32, 32]          73,728
#        BatchNorm2d-4          [-1, 128, 32, 32]             256
#             Conv2d-5          [-1, 128, 32, 32]         147,456
#        BatchNorm2d-6          [-1, 128, 32, 32]             256
#             Conv2d-7          [-1, 128, 32, 32]           8,192
#        BatchNorm2d-8          [-1, 128, 32, 32]             256
#         BasicBlock-9          [-1, 128, 32, 32]               0
#            Conv2d-10          [-1, 256, 16, 16]         294,912
#       BatchNorm2d-11          [-1, 256, 16, 16]             512
#            Conv2d-12          [-1, 256, 16, 16]         589,824
#       BatchNorm2d-13          [-1, 256, 16, 16]             512
#            Conv2d-14          [-1, 256, 16, 16]          32,768
#       BatchNorm2d-15          [-1, 256, 16, 16]             512
#        BasicBlock-16          [-1, 256, 16, 16]               0
#            Conv2d-17            [-1, 512, 8, 8]       1,179,648
#       BatchNorm2d-18            [-1, 512, 8, 8]           1,024
#            Conv2d-19            [-1, 512, 8, 8]       2,359,296
#       BatchNorm2d-20            [-1, 512, 8, 8]           1,024
#            Conv2d-21            [-1, 512, 8, 8]         131,072
#       BatchNorm2d-22            [-1, 512, 8, 8]           1,024
#        BasicBlock-23            [-1, 512, 8, 8]               0
#            Linear-24                   [-1, 10]          81,930
# ================================================================
# Total params: 4,906,058
# Trainable params: 4,906,058
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 13.25
# Params size (MB): 18.72
# Estimated Total Size (MB): 31.98
# ----------------------------------------------------------------

# %%
# reducing residual layer, reducing residual block, in planes = 128 and increasing number of chan modification
net5 = ResNet(BasicBlock, [1, 1, 1], [128, 256, 512], [1, 2, 2], 2048, in_planes=128)
models.append(net5)
net5 = net5.to(device)
summary(net5, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 128, 32, 32]           3,456
#        BatchNorm2d-2          [-1, 128, 32, 32]             256
#             Conv2d-3          [-1, 128, 32, 32]         147,456
#        BatchNorm2d-4          [-1, 128, 32, 32]             256
#             Conv2d-5          [-1, 128, 32, 32]         147,456
#        BatchNorm2d-6          [-1, 128, 32, 32]             256
#         BasicBlock-7          [-1, 128, 32, 32]               0
#             Conv2d-8          [-1, 256, 16, 16]         294,912
#        BatchNorm2d-9          [-1, 256, 16, 16]             512
#            Conv2d-10          [-1, 256, 16, 16]         589,824
#       BatchNorm2d-11          [-1, 256, 16, 16]             512
#            Conv2d-12          [-1, 256, 16, 16]          32,768
#       BatchNorm2d-13          [-1, 256, 16, 16]             512
#        BasicBlock-14          [-1, 256, 16, 16]               0
#            Conv2d-15            [-1, 512, 8, 8]       1,179,648
#       BatchNorm2d-16            [-1, 512, 8, 8]           1,024
#            Conv2d-17            [-1, 512, 8, 8]       2,359,296
#       BatchNorm2d-18            [-1, 512, 8, 8]           1,024
#            Conv2d-19            [-1, 512, 8, 8]         131,072
#       BatchNorm2d-20            [-1, 512, 8, 8]           1,024
#        BasicBlock-21            [-1, 512, 8, 8]               0
#            Linear-22                   [-1, 10]          20,490
# ================================================================
# Total params: 4,911,754
# Trainable params: 4,911,754
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 12.25
# Params size (MB): 18.74
# Estimated Total Size (MB): 31.00
# ----------------------------------------------------------------

# %%
# reducing residual layer, reducing residual block, increasing number of channels, modifying average pool kernel size, in_planes = 128 
net6 = ResNet(BasicBlock, [1, 1, 1], [128, 256, 512], [1, 2, 2], 8192, in_planes=128, avg_pool_size = 2)
models.append(net6)
net6 = net6.to(device)
summary(net6, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 128, 32, 32]           3,456
#        BatchNorm2d-2          [-1, 128, 32, 32]             256
#             Conv2d-3          [-1, 128, 32, 32]         147,456
#        BatchNorm2d-4          [-1, 128, 32, 32]             256
#             Conv2d-5          [-1, 128, 32, 32]         147,456
#        BatchNorm2d-6          [-1, 128, 32, 32]             256
#         BasicBlock-7          [-1, 128, 32, 32]               0
#             Conv2d-8          [-1, 256, 16, 16]         294,912
#        BatchNorm2d-9          [-1, 256, 16, 16]             512
#            Conv2d-10          [-1, 256, 16, 16]         589,824
#       BatchNorm2d-11          [-1, 256, 16, 16]             512
#            Conv2d-12          [-1, 256, 16, 16]          32,768
#       BatchNorm2d-13          [-1, 256, 16, 16]             512
#        BasicBlock-14          [-1, 256, 16, 16]               0
#            Conv2d-15            [-1, 512, 8, 8]       1,179,648
#       BatchNorm2d-16            [-1, 512, 8, 8]           1,024
#            Conv2d-17            [-1, 512, 8, 8]       2,359,296
#       BatchNorm2d-18            [-1, 512, 8, 8]           1,024
#            Conv2d-19            [-1, 512, 8, 8]         131,072
#       BatchNorm2d-20            [-1, 512, 8, 8]           1,024
#        BasicBlock-21            [-1, 512, 8, 8]               0
#            Linear-22                   [-1, 10]          81,930
# ================================================================
# Total params: 4,973,194
# Trainable params: 4,973,194
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 12.25
# Params size (MB): 18.97
# Estimated Total Size (MB): 31.23
# ----------------------------------------------------------------

# %% [markdown]
# ### Training and Testing them to compare performances

# %%
import os
import time

# %% [markdown]
# Change the model below to train each network.

# %%
# Specify the model configuration to use
model_num = 1

# %%
model = models[model_num-1].to(device)
if device == 'cuda':
    model = torch.nn.DataParallel(model)
    cudnn.benchmark = True

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
def calculate_accuracy(y_pred, y):
    top_pred = y_pred.argmax(1, keepdim = True)
    correct = top_pred.eq(y.view_as(top_pred)).sum()
    acc = correct.float() / y.shape[0]
    return acc

# %% [markdown]
# Change the checkpoint name below to save different model checkpoints. We are saving the model state, validation accuracy for each epoch in checkpoints. We are also printing validation loss and accuracy for each epoch.

# %%
def train(net, iterator, optimizer, criterion, device):
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(iterator):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()
        total += targets.size(0)

    return train_loss / (batch_idx+1), 100.*correct / total

# %%
def evaluate(net, iterator, criterion, device):
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(iterator):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            correct += predicted.eq(targets).sum().item()
            total += targets.size(0)


    return test_loss / (batch_idx+1), 100.*correct / total

# %%
import time

def current_seconds_time():
    return round(time.time())

# %%
EPOCHS = 100

total_start_time = current_seconds_time()
best_valid_acc = 0
for epoch in range(EPOCHS):
  start_time = current_seconds_time()
  train_loss, train_accuracy = train(model, train_iterator, optimizer, criterion, device)
  valid_loss, valid_accuracy = evaluate(model, valid_iterator, criterion, device)
  if valid_accuracy > best_valid_acc:
    save_location = f"{proj_root}/model_"+str(model_num)+".pt"
    torch.save(model, save_location)
    best_valid_acc = valid_accuracy
  end_time = current_seconds_time()
  elapsed_mins, elapsed_secs = epoch_time(start_time, end_time)
  print('Epoch %s,\n Train loss %s,\n Valid loss %s,\n Train accuracy %s,\n Valid accuracy %s \n Elapsed time: %s m %s s\n\n'%(epoch, train_loss, valid_loss, train_accuracy, valid_accuracy, elapsed_mins, elapsed_secs))
total_end_time = current_seconds_time()
full_mins, full_secs = epoch_time(total_start_time, total_end_time)
# Out:
# Epoch 0,
#  Train loss 0.5717906671660867,
#  Valid loss 0.7053496247529983,
#  Train accuracy 79.98,
#  Valid accuracy 76.92
#  Elapsed time: 0 m 28 s
#
#
# Epoch 1,
#  Train loss 0.504155941222879,
#  Valid loss 0.5214846813678742,
#  Train accuracy 82.70666666666666,
#  Valid accuracy 82.0
#  Elapsed time: 0 m 28 s
#
#
# Epoch 2,
#  Train loss 0.4509803851727735,
#  Valid loss 0.5795055288076401,
#  Train accuracy 84.42,
#  Valid accuracy 81.54
#  Elapsed time: 0 m 27 s
#
#
# Epoch 3,
#  Train loss 0.4201804973523725,
#  Valid loss 0.5129895806312561,
#  Train accuracy 85.42,
#  Valid accuracy 83.38
#  Elapsed time: 0 m 28 s
#
#
# Epoch 4,
#  Train loss 0.38094444543292577,
#  Valid loss 0.46957295358181,
#  Train accuracy 86.66444444444444,
#  Valid accuracy 84.98
#  Elapsed time: 0 m 27 s
#
#
# Epoch 5,
#  Train loss 0.35370434261858463,
#  Valid loss 0.4688499438762665,
#  Train accuracy 87.66444444444444,
#  Valid accuracy 85.04
#  Elapsed time: 0 m 27 s
#
#
# Epoch 6,
#  Train loss 0.3247490962543948,
#  Valid loss 0.4824626955389977,
#  Train accuracy 88.74888888888889,
#  Valid accuracy 84.84
#  Elapsed time: 0 m 27 s
#
#
# Epoch 7,
#  Train loss 0.30416849886321207,
#  Valid loss 0.4179018372297287,
#  Train accuracy 89.32444444444444,
#  Valid accuracy 86.64
#  Elapsed time: 0 m 28 s
#
#
# Epoch 8,
#  Train loss 0.28383167464794085,
#  Valid loss 0.3916673251986504,
#  Train accuracy 90.0911111111111,
#  Valid accuracy 88.02
#  Elapsed time: 0 m 27 s
#
#
# Epoch 9,
#  Train loss 0.26045492198318243,
#  Valid loss 0.3724332815408707,
#  Train accuracy 90.92,
#  Valid accuracy 88.18
#  Elapsed time: 0 m 28 s
#
#
# Epoch 10,
#  Train loss 0.24864839235405353,
#  Valid loss 0.3935401213169098,
#  Train accuracy 91.28222222222222,
#  Valid accuracy 87.8
#  Elapsed time: 0 m 27 s
#
#
# Epoch 11,
#  Train loss 0.22761685092171485,
#  Valid loss 0.3800608742237091,
#  Train accuracy 91.99777777777778,
#  Valid accuracy 88.16
#  Elapsed time: 0 m 28 s
#
#
# Epoch 12,
#  Train loss 0.21542488724331965,
#  Valid loss 0.3772994676232338,
#  Train accuracy 92.43777777777778,
#  Valid accuracy 89.38
#  Elapsed time: 0 m 28 s
#
#
# Epoch 13,
#  Train loss 0.20126456352458758,
#  Valid loss 0.3743671503663063,
#  Train accuracy 92.87333333333333,
#  Valid accuracy 88.46
#  Elapsed time: 0 m 27 s
#
#
# Epoch 14,
#  Train loss 0.18640425739894537,
#  Valid loss 0.43422409892082214,
#  Train accuracy 93.59555555555555,
#  Valid accuracy 87.34
#  Elapsed time: 0 m 27 s
#
#
# Epoch 15,
#  Train loss 0.17437028232961893,
#  Valid loss 0.39971758633852006,
#  Train accuracy 93.84,
#  Valid accuracy 88.58
#  Elapsed time: 0 m 27 s
#
#
# Epoch 16,
#  Train loss 0.16763388479805805,
#  Valid loss 0.3999353687465191,
#  Train accuracy 94.05555555555556,
#  Valid accuracy 89.02
#  Elapsed time: 0 m 28 s
#
#
# Epoch 17,
#  Train loss 0.1546459612859921,
#  Valid loss 0.36763768702745436,
#  Train accuracy 94.52888888888889,
#  Valid accuracy 89.68
#  Elapsed time: 0 m 27 s
#
#
# Epoch 18,
#  Train loss 0.14207992428617383,
#  Valid loss 0.3713553503155708,
#  Train accuracy 94.9088888888889,
#  Valid accuracy 89.52
#  Elapsed time: 0 m 27 s
#
#
# Epoch 19,
#  Train loss 0.13720594024793667,
#  Valid loss 0.39773645117878914,
#  Train accuracy 95.16222222222223,
#  Valid accuracy 89.36
#  Elapsed time: 0 m 27 s
#
#
# Epoch 20,
#  Train loss 0.132452719156969,
#  Valid loss 0.3898089162260294,
#  Train accuracy 95.30888888888889,
#  Valid accuracy 89.9
#  Elapsed time: 0 m 28 s
#
#
# Epoch 21,
#  Train loss 0.12208039034157991,
#  Valid loss 0.36662049978971484,
#  Train accuracy 95.60888888888888,
#  Valid accuracy 90.2
#  Elapsed time: 0 m 28 s
#
#
# Epoch 22,
#  Train loss 0.11518832196650858,
#  Valid loss 0.399645182788372,
#  Train accuracy 95.94666666666667,
#  Valid accuracy 89.72
#  Elapsed time: 0 m 27 s
#
#
# Epoch 23,
#  Train loss 0.10991166943726553,
#  Valid loss 0.4294114738702774,
#  Train accuracy 96.04222222222222,
#  Valid accuracy 89.3
#  Elapsed time: 0 m 27 s
#
#
# Epoch 24,
#  Train loss 0.10243038785516877,
#  Valid loss 0.3492753864824772,
#  Train accuracy 96.42222222222222,
#  Valid accuracy 90.62
#  Elapsed time: 0 m 27 s
#
#
# Epoch 25,
#  Train loss 0.10121619134125384,
#  Valid loss 0.4165118646621704,
#  Train accuracy 96.37333333333333,
#  Valid accuracy 89.18
#  Elapsed time: 0 m 28 s
#
#
# Epoch 26,
#  Train loss 0.09397302956891838,
#  Valid loss 0.41423570543527605,
#  Train accuracy 96.7,
#  Valid accuracy 89.82
#  Elapsed time: 0 m 27 s
#
#
# Epoch 27,
#  Train loss 0.08636777262753723,
#  Valid loss 0.43734209299087523,
#  Train accuracy 96.96,
#  Valid accuracy 89.78
#  Elapsed time: 0 m 27 s
#
#
# Epoch 28,
#  Train loss 0.08753610541514883,
#  Valid loss 0.3823902866244316,
#  Train accuracy 96.86666666666666,
#  Valid accuracy 90.34
#  Elapsed time: 0 m 27 s
#
#
# Epoch 29,
#  Train loss 0.07730030284570107,
#  Valid loss 0.40270587146282194,
#  Train accuracy 97.26222222222222,
#  Valid accuracy 90.02
#  Elapsed time: 0 m 27 s
#
#
# Epoch 30,
#  Train loss 0.07928308363823983,
#  Valid loss 0.436917719244957,
#  Train accuracy 97.11777777777777,
#  Valid accuracy 89.68
#  Elapsed time: 0 m 28 s
#
#
# Epoch 31,
#  Train loss 0.07038948887599293,
#  Valid loss 0.425048326253891,
#  Train accuracy 97.53111111111112,
#  Valid accuracy 90.26
#  Elapsed time: 0 m 27 s
#
#
# Epoch 32,
#  Train loss 0.07564633067125794,
#  Valid loss 0.4202003337442875,
#  Train accuracy 97.34666666666666,
#  Valid accuracy 90.48
#  Elapsed time: 0 m 27 s
#
#
# Epoch 33,
#  Train loss 0.06726057898247911,
#  Valid loss 0.41889057993888856,
#  Train accuracy 97.58888888888889,
#  Valid accuracy 90.32
#  Elapsed time: 0 m 27 s
#
#
# Epoch 34,
#  Train loss 0.07137870497271334,
#  Valid loss 0.4023251697421074,
#  Train accuracy 97.51777777777778,
#  Valid accuracy 90.48
#  Elapsed time: 0 m 27 s
#
#
# Epoch 35,
#  Train loss 0.06488323158489286,
#  Valid loss 0.411725300848484,
#  Train accuracy 97.64,
#  Valid accuracy 90.94
#  Elapsed time: 0 m 28 s
#
#
# Epoch 36,
#  Train loss 0.05840063003018837,
#  Valid loss 0.4228689309209585,
#  Train accuracy 97.90222222222222,
#  Valid accuracy 90.78
#  Elapsed time: 0 m 27 s
#
#
# Epoch 37,
#  Train loss 0.05679269401959821,
#  Valid loss 0.4255570922791958,
#  Train accuracy 97.90444444444445,
#  Valid accuracy 90.48
#  Elapsed time: 0 m 27 s
#
#
# Epoch 38,
#  Train loss 0.060395540297825144,
#  Valid loss 0.4027498368918896,
#  Train accuracy 97.96666666666667,
#  Valid accuracy 90.74
#  Elapsed time: 0 m 27 s
#
#
# Epoch 39,
#  Train loss 0.05287587977231438,
#  Valid loss 0.4269468829035759,
#  Train accuracy 98.16444444444444,
#  Valid accuracy 90.78
#  Elapsed time: 0 m 27 s
#
#
# Epoch 40,
#  Train loss 0.05189850198142019,
#  Valid loss 0.40019864529371263,
#  Train accuracy 98.19111111111111,
#  Valid accuracy 91.52
#  Elapsed time: 0 m 28 s
#
#
# Epoch 41,
#  Train loss 0.05400855342238422,
#  Valid loss 0.4022364339232445,
#  Train accuracy 98.12666666666667,
#  Valid accuracy 91.26
#  Elapsed time: 0 m 27 s
#
#
# Epoch 42,
#  Train loss 0.04509246908657422,
#  Valid loss 0.462470410913229,
#  Train accuracy 98.3711111111111,
#  Valid accuracy 90.58
#  Elapsed time: 0 m 27 s
#
#
# Epoch 43,
#  Train loss 0.05191923001786398,
#  Valid loss 0.517581893056631,
#  Train accuracy 98.11777777777777,
#  Valid accuracy 90.4
#  Elapsed time: 0 m 28 s
#
#
# Epoch 44,
#  Train loss 0.04989015480334109,
#  Valid loss 0.4855788585543632,
#  Train accuracy 98.16888888888889,
#  Valid accuracy 90.38
#  Elapsed time: 0 m 27 s
#
#
# Epoch 45,
#  Train loss 0.050884368359799155,
#  Valid loss 0.41175189390778544,
#  Train accuracy 98.19111111111111,
#  Valid accuracy 91.18
#  Elapsed time: 0 m 27 s
#
#
# Epoch 46,
#  Train loss 0.04344711163933177,
#  Valid loss 0.4392285993695259,
#  Train accuracy 98.45111111111112,
#  Valid accuracy 91.08
#  Elapsed time: 0 m 27 s
#
#
# Epoch 47,
#  Train loss 0.04284456290968757,
#  Valid loss 0.4879221683740616,
#  Train accuracy 98.48444444444445,
#  Valid accuracy 90.52
#  Elapsed time: 0 m 28 s
#
#
# Epoch 48,
#  Train loss 0.04333272669067479,
#  Valid loss 0.444219718426466,
#  Train accuracy 98.49111111111111,
#  Valid accuracy 91.2
#  Elapsed time: 0 m 27 s
#
#
# Epoch 49,
#  Train loss 0.044883008683841166,
#  Valid loss 0.4677488312125206,
#  Train accuracy 98.46222222222222,
#  Valid accuracy 90.84
#  Elapsed time: 0 m 28 s
#
#
# Epoch 50,
#  Train loss 0.03884171568047763,
#  Valid loss 0.4528582113981247,
#  Train accuracy 98.67333333333333,
#  Valid accuracy 90.9
#  Elapsed time: 0 m 27 s
#
#
# Epoch 51,
#  Train loss 0.042919608153169975,
#  Valid loss 0.4692230248451233,
#  Train accuracy 98.43777777777778,
#  Valid accuracy 90.46
#  Elapsed time: 0 m 27 s
#
#
# Epoch 52,
#  Train loss 0.03864993324069391,
#  Valid loss 0.4968040469288826,
#  Train accuracy 98.66222222222223,
#  Valid accuracy 90.84
#  Elapsed time: 0 m 28 s
#
#
# Epoch 53,
#  Train loss 0.03780990721729309,
#  Valid loss 0.4415585179626942,
#  Train accuracy 98.72666666666667,
#  Valid accuracy 91.2
#  Elapsed time: 0 m 27 s
#
#
# Epoch 54,
#  Train loss 0.037454243408071554,
#  Valid loss 0.5107661536335946,
#  Train accuracy 98.62666666666667,
#  Valid accuracy 90.38
#  Elapsed time: 0 m 27 s
#
#
# Epoch 55,
#  Train loss 0.041703046236679336,
#  Valid loss 0.5286811769008637,
#  Train accuracy 98.54222222222222,
#  Valid accuracy 90.44
#  Elapsed time: 0 m 27 s
#
#
# Epoch 56,
#  Train loss 0.0322856246222562,
#  Valid loss 0.4358108860254288,
#  Train accuracy 98.87555555555555,
#  Valid accuracy 92.06
#  Elapsed time: 0 m 28 s
#
#
# Epoch 57,
#  Train loss 0.03628149179183476,
#  Valid loss 0.4912355583906174,
#  Train accuracy 98.70444444444445,
#  Valid accuracy 90.66
#  Elapsed time: 0 m 28 s
#
#
# Epoch 58,
#  Train loss 0.0366862053091278,
#  Valid loss 0.45185045078396796,
#  Train accuracy 98.74444444444444,
#  Valid accuracy 91.36
#  Elapsed time: 0 m 27 s
#
#
# Epoch 59,
#  Train loss 0.02605551224504862,
#  Valid loss 0.446412433385849,
#  Train accuracy 99.06888888888889,
#  Valid accuracy 91.58
#  Elapsed time: 0 m 27 s
#
#
# Epoch 60,
#  Train loss 0.03182615037902989,
#  Valid loss 0.43391398306936024,
#  Train accuracy 98.92222222222222,
#  Valid accuracy 91.5
#  Elapsed time: 0 m 27 s
#
#
# Epoch 61,
#  Train loss 0.03418301869665315,
#  Valid loss 0.502087648063898,
#  Train accuracy 98.78,
#  Valid accuracy 90.82
#  Elapsed time: 0 m 28 s
#
#
# Epoch 62,
#  Train loss 0.03169863915073537,
#  Valid loss 0.47615170121192935,
#  Train accuracy 98.90666666666667,
#  Valid accuracy 91.1
#  Elapsed time: 0 m 27 s
#
#
# Epoch 63,
#  Train loss 0.030329899956003912,
#  Valid loss 0.49839125216007235,
#  Train accuracy 98.89777777777778,
#  Valid accuracy 90.38
#  Elapsed time: 0 m 27 s
#
#
# Epoch 64,
#  Train loss 0.03279779509532752,
#  Valid loss 0.48399341821670533,
#  Train accuracy 98.83333333333333,
#  Valid accuracy 91.28
#  Elapsed time: 0 m 28 s
#
#
# Epoch 65,
#  Train loss 0.02696670376330572,
#  Valid loss 0.4625064155459404,
#  Train accuracy 99.10444444444444,
#  Valid accuracy 91.46
#  Elapsed time: 0 m 27 s
#
#
# Epoch 66,
#  Train loss 0.033234311877921835,
#  Valid loss 0.5094799646735191,
#  Train accuracy 98.85111111111111,
#  Valid accuracy 90.74
#  Elapsed time: 0 m 28 s
#
#
# Epoch 67,
#  Train loss 0.031771073924822056,
#  Valid loss 0.5176634129881859,
#  Train accuracy 98.95333333333333,
#  Valid accuracy 90.52
#  Elapsed time: 0 m 27 s
#
#
# Epoch 68,
#  Train loss 0.03193968230665301,
#  Valid loss 0.45601045042276384,
#  Train accuracy 98.84666666666666,
#  Valid accuracy 91.64
#  Elapsed time: 0 m 27 s
#
#
# Epoch 69,
#  Train loss 0.028615165971462953,
#  Valid loss 0.4580075404047966,
#  Train accuracy 99.01777777777778,
#  Valid accuracy 91.36
#  Elapsed time: 0 m 27 s
#
#
# Epoch 70,
#  Train loss 0.023898242079502034,
#  Valid loss 0.48604696929454805,
#  Train accuracy 99.2,
#  Valid accuracy 91.58
#  Elapsed time: 0 m 28 s
#
#
# Epoch 71,
#  Train loss 0.027498845575213305,
#  Valid loss 0.484542376101017,
#  Train accuracy 99.03555555555556,
#  Valid accuracy 91.52
#  Elapsed time: 0 m 27 s
#
#
# Epoch 72,
#  Train loss 0.027048201407028086,
#  Valid loss 0.4587182553112507,
#  Train accuracy 99.05555555555556,
#  Valid accuracy 91.42
#  Elapsed time: 0 m 27 s
#
#
# Epoch 73,
#  Train loss 0.02605342695592712,
#  Valid loss 0.4540325066447258,
#  Train accuracy 99.06444444444445,
#  Valid accuracy 91.74
#  Elapsed time: 0 m 27 s
#
#
# Epoch 74,
#  Train loss 0.028622293423474977,
#  Valid loss 0.4990487538278103,
#  Train accuracy 98.95333333333333,
#  Valid accuracy 90.72
#  Elapsed time: 0 m 27 s
#
#
# Epoch 75,
#  Train loss 0.027114438800543376,
#  Valid loss 0.4685464063286781,
#  Train accuracy 99.08,
#  Valid accuracy 91.78
#  Elapsed time: 0 m 28 s
#
#
# Epoch 76,
#  Train loss 0.025501492774558508,
#  Valid loss 0.48269752219319345,
#  Train accuracy 99.10666666666667,
#  Valid accuracy 91.86
#  Elapsed time: 0 m 27 s
#
#
# Epoch 77,
#  Train loss 0.029483680719501783,
#  Valid loss 0.4647158861905336,
#  Train accuracy 99.03333333333333,
#  Valid accuracy 92.12
#  Elapsed time: 0 m 27 s
#
#
# Epoch 78,
#  Train loss 0.02446362290224484,
#  Valid loss 0.4799161920696497,
#  Train accuracy 99.18,
#  Valid accuracy 91.28
#  Elapsed time: 0 m 28 s
#
#
# Epoch 79,
#  Train loss 0.01998005908519024,
#  Valid loss 0.5057052886486053,
#  Train accuracy 99.27333333333333,
#  Valid accuracy 91.18
#  Elapsed time: 0 m 28 s
#
#
# Epoch 80,
#  Train loss 0.022671507526286983,
#  Valid loss 0.4920436868071556,
#  Train accuracy 99.24888888888889,
#  Valid accuracy 91.54
#  Elapsed time: 0 m 27 s
#
#
# Epoch 81,
#  Train loss 0.025307796999351758,
#  Valid loss 0.4931708520650864,
#  Train accuracy 99.11555555555556,
#  Valid accuracy 91.56
#  Elapsed time: 0 m 27 s
#
#
# Epoch 82,
#  Train loss 0.02544124282907102,
#  Valid loss 0.5067471417784691,
#  Train accuracy 99.10222222222222,
#  Valid accuracy 91.48
#  Elapsed time: 0 m 27 s
#
#
# Epoch 83,
#  Train loss 0.020723025254648583,
#  Valid loss 0.4845138590037823,
#  Train accuracy 99.27777777777777,
#  Valid accuracy 91.6
#  Elapsed time: 0 m 27 s
#
#
# Epoch 84,
#  Train loss 0.018392889988800478,
#  Valid loss 0.4892733614146709,
#  Train accuracy 99.42444444444445,
#  Valid accuracy 91.84
#  Elapsed time: 0 m 28 s
#
#
# Epoch 85,
#  Train loss 0.023807043214302128,
#  Valid loss 0.5265622863173485,
#  Train accuracy 99.14888888888889,
#  Valid accuracy 90.9
#  Elapsed time: 0 m 27 s
#
#
# Epoch 86,
#  Train loss 0.020761638920785943,
#  Valid loss 0.4599896633625031,
#  Train accuracy 99.29777777777778,
#  Valid accuracy 91.76
#  Elapsed time: 0 m 27 s
#
#
# Epoch 87,
#  Train loss 0.02596874014265764,
#  Valid loss 0.5092317312210798,
#  Train accuracy 99.08222222222223,
#  Valid accuracy 91.02
#  Elapsed time: 0 m 26 s
#
#
# Epoch 88,
#  Train loss 0.023310394307124872,
#  Valid loss 0.5286790752410888,
#  Train accuracy 99.20444444444445,
#  Valid accuracy 91.0
#  Elapsed time: 0 m 28 s
#
#
# Epoch 89,
#  Train loss 0.020145416266380133,
#  Valid loss 0.47559950202703477,
#  Train accuracy 99.28444444444445,
#  Valid accuracy 91.46
#  Elapsed time: 0 m 27 s
#
#
# Epoch 90,
#  Train loss 0.02062591960053727,
#  Valid loss 0.5054847502708435,
#  Train accuracy 99.2688888888889,
#  Valid accuracy 91.42
#  Elapsed time: 0 m 27 s
#
#
# Epoch 91,
#  Train loss 0.0224539785641272,
#  Valid loss 0.49204587668180466,
#  Train accuracy 99.21777777777778,
#  Valid accuracy 91.58
#  Elapsed time: 0 m 27 s
#
#
# Epoch 92,
#  Train loss 0.01919224270485839,
#  Valid loss 0.5120244930684567,
#  Train accuracy 99.2911111111111,
#  Valid accuracy 91.52
#  Elapsed time: 0 m 27 s
#
#
# Epoch 93,
#  Train loss 0.018521676175541044,
#  Valid loss 0.4778013984113932,
#  Train accuracy 99.33333333333333,
#  Valid accuracy 91.58
#  Elapsed time: 0 m 28 s
#
#
# Epoch 94,
#  Train loss 0.01892264016218674,
#  Valid loss 0.4675878730416298,
#  Train accuracy 99.3711111111111,
#  Valid accuracy 91.88
#  Elapsed time: 0 m 27 s
#
#
# Epoch 95,
#  Train loss 0.021080814855271125,
#  Valid loss 0.4955040930211544,
#  Train accuracy 99.27777777777777,
#  Valid accuracy 91.26
#  Elapsed time: 0 m 27 s
#
#
# Epoch 96,
#  Train loss 0.020657736067484868,
#  Valid loss 0.5097921493649483,
#  Train accuracy 99.27333333333333,
#  Valid accuracy 91.06
#  Elapsed time: 0 m 27 s
#
#
# Epoch 97,
#  Train loss 0.019872036176324895,
#  Valid loss 0.46947553992271424,
#  Train accuracy 99.3,
#  Valid accuracy 92.04
#  Elapsed time: 0 m 28 s
#
#
# Epoch 98,
#  Train loss 0.01799298534156564,
#  Valid loss 0.47423736870288846,
#  Train accuracy 99.36888888888889,
#  Valid accuracy 91.96
#  Elapsed time: 0 m 27 s
#
#
# Epoch 99,
#  Train loss 0.01722390470290107,
#  Valid loss 0.4559671294689178,
#  Train accuracy 99.38666666666667,
#  Valid accuracy 92.02
#  Elapsed time: 0 m 27 s

# %%
print(f"Total time elapsed: {full_mins}m {full_secs}s")
print(f"Best valid accuracy: {best_valid_acc}%")
# Out:
# Total time elapsed: 45m 30s
# Best valid accuracy: 92.12%

# %% [markdown]
# ## Visualizing Performance of different models

# %%
overall_result = []
time_taken = [20, 33, 27, 27, 28, 28]
for i, _ in enumerate(models[:model_num]):
  indiv_result = []
  save_location =  f"{proj_root}/model_"+str(i+1)+".pt"
  test_model = torch.load(save_location)
  test_loss, test_acc = evaluate(test_model, test_iterator, criterion, device)
  indiv_result.append(i+1)
  indiv_result.append(test_loss)
  indiv_result.append(test_acc)
  indiv_result.append(time_taken[i])
  overall_result.append(indiv_result)
  # print(test_loss, test_acc)

print(tabulate(overall_result, headers=['Model', 'Test Loss', 'Test Accuracy', 'Time Taken for training in minutes']))
# Out:
#   Model    Test Loss    Test Accuracy    Time Taken for training in minutes
# -------  -----------  ---------------  ------------------------------------
#       1     0.481737            91.34                                    20

# %% [markdown]
# ## Evaluating the best model
#
# Finally, let's plot the confusion matrix of this model.

# %%
best_model_index = 1
save_location =  f"{proj_root}/model_"+str(best_model_index)+".pt"
best_model = torch.load(save_location)

# %%
evaluate(best_model, test_iterator, criterion, device)
# Out:
# (0.4817370168864727, 91.34)

# %%
def get_predictions(net, iterator, criterion, device):
    net.eval()
    correct = 0
    total = 0
    labels = []
    predicts = []
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(iterator):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)

            loss = criterion(outputs, targets)
            _, predicted = outputs.max(1)
            labels.append(targets)
            predicts.append(predicted)
            correct += predicted.eq(targets).sum().item()
            total += targets.size(0)


    labels = torch.cat(labels, dim = 0)
    predicts = torch.cat(predicts, dim = 0)
    return labels, predicts

# %%
labels, pred_labels = get_predictions(best_model, test_iterator, criterion, device)

# %%
def plot_confusion_matrix(labels, pred_labels, classes):
    
    fig = plt.figure(figsize = (10, 10));
    ax = fig.add_subplot(1, 1, 1);
    cm = confusion_matrix(labels, pred_labels);
    cm = ConfusionMatrixDisplay(cm, display_labels = classes);
    cm.plot(values_format = 'd', cmap = 'Blues', ax = ax)
    plt.xticks(rotation = 20)

# %%
plot_confusion_matrix(labels.cpu(), pred_labels.cpu(), testset.classes)

# %% [markdown]
# ## References

# %% [markdown]
# 1. https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html
# 2. https://github.com/kuangliu/pytorch-cifar
# 3. https://gist.github.com/kevinzakka/d33bf8d6c7f06a9d8c76d97a7879f5cb
